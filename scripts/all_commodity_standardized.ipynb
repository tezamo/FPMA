# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\morte\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\morte\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\morte\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\morte\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\morte\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\morte\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ╔════════════════════════════════════╗
# ║             TEZAMO                 ║
# ╚════════════════════════════════════╝
import requests
import pandas as pd
import numpy as np
from time import sleep

# CONFIG
OUTPUT_FILE = "all_commodity_standardized.csv"

HARDCODED_RATE_CURRENCIES = {"BYR", "TMT"}


TMT_RATE = 3.5



BYR_YEARLY_RATES = {
    2009: 0.281,
    2010: 0.299,
    2011: 0.498,
    2012: 0.830,
    2013: 0.904,
    2014: 1.048,
. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.
. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.

. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.

. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.

. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.


. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.
.
.
. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.
.
.
. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.
.
.
.
. 
.
. 
.  "Full implementation removed for privacy"
. 
. 
.
.
.
.
.
.
.
.


with warnings.catch_warnings():

    warnings.simplefilter("ignore", FutureWarning)
    final_df = pd.concat(all_rows, ignore_index=True)

final_df = final_df.sort_values(
    ["country", "market", "commodity_name", "date"]
).reset_index(drop=True)

print(f"\nTotal rows          : {len(final_df):,}")
print(f"Missing price_usd   : {final_df['price_usd'].isna().sum():,}")
print(f"Missing price_local : {final_df['price_local'].isna().sum():,}")
print(f"\nFill method breakdown:")
print(final_df["fill_method"].value_counts().to_string())

final_df.to_csv(OUTPUT_FILE, index=False)
print(f"\nSaved → {OUTPUT_FILE}")

# ╔════════════════════════════════════╗
# ║             TEZAMO                 ║
# ╚════════════════════════════════════╝
# Out:
# ============================================================
# FETCHING INTERNATIONAL SERIES
# ============================================================
#   [International] Groundnuts (US Runners 40/50, c.i.f. Rotterdam) — 361 rows
#   [International] Cassava Chips (Shipments to China, f.o.b. Koh Sichang) — 206 rows
#   [International] Diammonium phosphate, DAP (P fertilizer) — 313 rows
#   [International] Dairy: Skim Milk Powder (European & Oceania average indicative export prices, f.o.b) — 433 rows
#   [International] Fish oil (Any origin, c.i.f. North West Europe) — 361 rows
#   [International] Crude oil (Brent) — 313 rows
#   [International] Wheat (CWRS, 13.5%) — 313 rows
#   [International] Rice (Super Kernel White Basmati 2%) — 313 rows
#   [International] Sorghum — 296 rows
#   [International] Palmkernel meal (Expeller pellets, 21/23%, c.i.f. Rotterdam) — 361 rows
#   [International] Barley (feed) — 308 rows
#   [International] Meat: Pig meat (Meat of swine, fresh, chilled or frozen) — 433 rows
#   [International] Dairy: Cheddar Cheese (European & Oceania average indicative export prices, f.o.b) — 433 rows
#   [International] Wheat (milling, d.a.p. Saryagash station) — 99 rows
#   [International] Rice (Parboiled 100%) — 313 rows
#   [International] Tea — 226 rows
#   [International] Sorghum (US No. 2, Yellow) — 261 rows
#   [International] Sunflowerseed (EU, c.i.f. Amsterdam) — 241 rows
#   [International] Bananas (Main Brands Central America, Delivered at Terminal) — 350 rows
#   [International] Maize (US No. 2, White) — 244 rows
#   [International] Maize (Up River) — 313 rows
#   [International] Soybean (US, c.i.f. Rotterdam) — 361 rows
#   [International] Soybean meal (44/45%, Hamburg, f.o.b. ex-mill) — 361 rows
#   [International] Wheat (milling, 12.5%) — 259 rows
#   [International] Rice (5% broken, long grain white, f.o.b., f.c.l.) — 241 rows
#   [International] Soybean oil (Dutch, f.o.b. ex-mill) — 361 rows
#   [International] Jute BWD (f.o.b. Mongla, at sight)/from 2006 Jute BTD (f.o.b Bangladesh Port) — 262 rows
#   [International] Maize (US No. 2, Yellow) — 313 rows
#   [International] Cassava Flour/Starch (Super High Grade, f.o.b. Bangkok) — 268 rows
#   [International] Australia, Meat: Ovine (National Heavy Lamb Indicator Value) — 433 rows
#   [International] Wheat (US No. 2, Soft Red Winter) — 313 rows
#   [International] Wheat (feed, <11%) — 308 rows
#   [International] Dairy: Whole Milk Powder (European & Oceania average indicative export prices, f.o.b) — 433 rows
#   [International] Sisal (Brazil Bahia, No. 3/ from 2013 Bahia Type 3 DB, f.o.b. Salvador) — 468 rows
#   [International] Triple Superphosphate, TSP (P fertilizer) — 313 rows
#   [International] Sisal (East African, No. 3L - Tanzania/Kenya c.i.f. - from 2007 f.o.b.) — 468 rows
#   [International] Rice (Glutinous 10%) — 313 rows
#   [International] Rice (25% broken) — 313 rows
#   [International] Coconut oil (Philippines, c.i.f. Rotterdam) — 361 rows
#   [International] Tea — 226 rows
#   [International] Meat: Bovine (Fresh, chilled or frozen) — 433 rows
#   [International] Wheat (US No. 2, Hard Red Winter) — 313 rows
#   [International] Meat: Pig meat (Fresh, chilled or frozen) — 433 rows
#   [International] Rice (Fragrant 100%) — 313 rows
#   [International] Rice (25% broken) — 313 rows
#   [International] Meat: Poultry (Chicken cuts and edible offal, fresh, chilled or frozen) — 433 rows
#   [International] New Zealand, Meat: Ovine (Lamb Average Export Value) — 433 rows
#   [International] Wheat (grade 1, Rouen) — 219 rows
#   [International] Barley (feed) — 282 rows
#   [International] Wheat (offer, f.o.b., deep-sea ports) — 232 rows
#   [International] Bananas (Main brands Central and South America, Free on Truck) — 372 rows
#   [International] Dairy: Butter (European & Oceania average indicative export prices, f.o.b) — 433 rows
#   [International] Rapeseed meal (34%, Hamburg, f.o.b. ex-mill) — 361 rows
#   [International] Sunflower oil (f.o.b. North West European Ports) — 361 rows
#   [International] Wheat (milling, offer, f.o.b.) — 313 rows
#   [International] Barley (feed) — 308 rows
#   [International] Meat: Poultry (Meat and edible offal. Fresh, chilled or frozen) — 433 rows
#   [International] Phosphate rock (P fertilizer) — 313 rows
#   [International] Bananas (Other Brands Central America, Delivered at Terminal) — 350 rows
#   [International] Tea — 430 rows
#   [International] Wheat (ASW) — 308 rows
#   [International] Bananas (Main Brands Central America, Delivered at Terminal) — 350 rows
#   [International] Sisal (East African, UG - Tanzania/Kenya c.i.f. - from 2007 f.o.b.) — 468 rows
#   [International] Rice (Thai 100% B white) — 445 rows
#   [International] Rice (US No. 2, 4% Long Grain) — 313 rows
#   [International] Maize (feed) — 193 rows
#   [International] Maize (feed) — 214 rows
#   [International] Rapeseed (Europe, 00, c.i.f. Hamburg) — 361 rows
#   [International] Rice (Thai A1 Super) — 445 rows
#   [International] Bananas — 169 rows
#   [International] Crude oil (WTI) — 313 rows
#   [International] Bananas — 348 rows
#   [International] Bananas (Other Brands Central America, Delivered at Terminal) — 350 rows
#   [International] Wheat (12%, Up River) — 313 rows
#   [International] Australia, Meat: Bovine (90CL Boneless Beef, FOB export prices to the United States of America) — 433 rows
#   [International] Maize (offer, f.o.b.) — 313 rows
#   [International] Soybean (US, No. 1 yellow, f.o.b.) — 348 rows
#   [International] Rice (5% broken) — 313 rows
#   [International] Rice (25% broken) — 373 rows
#   [International] Rice (5% broken) — 313 rows
#   [International] Potassium chloride, muriate of potash (K fertilizer) — 313 rows
#   [International] Rape oil (Dutch, f.o.b. ex-mill) — 361 rows
#   [International] Urea (N fertilizer) — 313 rows
#   [International] Fish Meal (64/65% Bremen f.c.a.) — 253 rows
#   [International] Meat: Pig meat (Market price for pig carcase grade E) — 433 rows
#   [International] Sugar — 397 rows
#   [International] Palm oil (Crude, c.i.f. Rotterdam) — 361 rows
#   [International] Meat: Bovine (Fresh, chilled or frozen) — 433 rows
#   [International] Rice (25% broken) — 313 rows
#   [International] Groundnut oil (Any origin, c.i.f. Rotterdam) — 342 rows
#
# ============================================================
# FETCHING DOMESTIC SERIES
# ============================================================
# Total domestic series: 3394
#   [Domestic] Bread | Kabul, Afghanistan | 314 rows | filled 1/2 missing USD
#   [Domestic] Bread | Herat, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat | Kandahar, Afghanistan | 314 rows | filled 1/4 missing USD
#   [Domestic] Wheat (flour) | Herat, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Kandahar, Afghanistan | 314 rows | filled 1/4 missing USD
#   [Domestic] Wheat (flour) | Jalalabad, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Bread | Kandahar, Afghanistan | 314 rows | filled 1/4 missing USD
#   [Domestic] Wheat | Jalalabad, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat | Herat, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Bread | Jalalabad, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Kabul, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat | Kabul, Afghanistan | 314 rows | filled 1/1 missing USD
#   [Domestic] Rice (long grain) | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Malanje, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Bengo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Bié, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Bié, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Bié, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Cunene, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cunene, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Bengo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Bengo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Malanje, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Malanje, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Bié, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Cunene, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Malanje, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Huíla, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Cuando Cubango, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Cunene, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Lunda Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cuanza Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Huambo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Moxico, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Bié, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Cabinda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Luanda, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | Benguela, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Lunda Norte, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Zaire, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Malanje, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Cunene, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Palm Oil | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Bengo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Namibe, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Rice (long grain) | Cuanza Sul, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Maize (flour) | Bengo, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Cassava | Uíge, Angola | 60 rows | filled 0/0 missing USD
#   [Domestic] Milk (fresh) | Patagonia, Argentina | 104 rows | filled 1/2 missing USD
#   [Domestic] Wheat (flour) | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Sugar | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sugar | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Milk (fresh) | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Pasta | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Milk (fresh) | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Rice (white) | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Patagonia, Argentina | 104 rows | filled 1/2 missing USD
#   [Domestic] Sugar | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sugar | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Pasta | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Bread (French type) | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Patagonia, Argentina | 104 rows | filled 1/2 missing USD
#   [Domestic] Pasta | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Pasta | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Greater Buenos Aires, Argentina | 6 rows | filled 1/1 missing USD
#   [Domestic] Wheat | Rosario, Argentina | 253 rows | filled 1/62 missing USD
#   [Domestic] Wheat | Córdoba, Argentina | 253 rows | filled 1/41 missing USD
#   [Domestic] Pasta | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sugar | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Greater Buenos Aires, Argentina | 6 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | Patagonia, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Maize (yellow) | Rosario, Argentina | 253 rows | filled 1/29 missing USD
#   [Domestic] Chicken (whole) | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sunflower oil | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Potatoes | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour) | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Beef meat | Noreste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Cuyo, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Sugar | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Milk (fresh) | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Pasta | Greater Buenos Aires, Argentina | 6 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | Greater Buenos Aires, Argentina | 6 rows | filled 1/1 missing USD
#   [Domestic] Eggs | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Milk (fresh) | Noroeste, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Milk (fresh) | Greater Buenos Aires, Argentina | 118 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | Pampeana, Argentina | 104 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour, first grade) | National Average, Armenia | 253 rows | filled 0/0 missing USD
#   [Domestic] Bread (first grade flour) | National Average, Armenia | 253 rows | filled 0/0 missing USD
#   [Domestic] Bread (high grade flour) | National Average, Armenia | 253 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, high grade) | National Average, Armenia | 253 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | National Average, Armenia | 217 rows | filled 0/0 missing USD
#   [Domestic] Chicken (whole) | National Average, Austria | 316 rows | filled 3/3 missing USD
#   [Domestic] Eggs | National Average, Austria | 349 rows | filled 36/36 missing USD
#   [Domestic] Wheat (bread making quality) | National Average, Austria | 373 rows | filled 56/77 missing USD
#   [Domestic] Milk (raw) | National Average, Austria | 252 rows | filled 0/1 missing USD
#   [Domestic] Wheat (durum) | National Average, Austria | 373 rows | filled 38/216 missing USD
#   [Domestic] Mutton meat | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, imported) | National Average, Azerbaijan | 133 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, mixed) | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Bread (high grade flour) | National Average, Azerbaijan | 240 rows | filled 0/0 missing USD
#   [Domestic] Beef meat | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Milk (not pasteurized) | National Average, Azerbaijan | 241 rows | filled 0/0 missing USD
#   [Domestic] Maize (white) | National Average, Burundi | 135 rows | filled 0/10 missing USD
#   [Domestic] Rice (low quality) | Bujumbura Rural, Burundi | 132 rows | filled 0/11 missing USD
#   [Domestic] Potatoes (sweet) | Bujumbura Rural, Burundi | 136 rows | filled 0/10 missing USD
#   [Domestic] Cassava (flour) | Kirundo, Burundi | 203 rows | filled 0/55 missing USD
#   [Domestic] Vegetable oil | Kirundo, Burundi | 96 rows | filled 0/9 missing USD
#   [Domestic] Potatoes (sweet) | Kirundo, Burundi | 203 rows | filled 0/55 missing USD
#   [Domestic] Rice (low quality) | Gitega, Burundi | 132 rows | filled 0/12 missing USD
#   [Domestic] Vegetable oil | Gitega, Burundi | 96 rows | filled 0/10 missing USD
#   [Domestic] Cassava (flour) | Bujumbura Mairie, Burundi | 180 rows | filled 0/20 missing USD
#   [Domestic] Cassava (flour) | National Average, Burundi | 135 rows | filled 0/10 missing USD
#   [Domestic] Potatoes (sweet) | Bujumbura Mairie, Burundi | 180 rows | filled 0/21 missing USD
#   [Domestic] Vegetable oil | Bujumbura Mairie, Burundi | 96 rows | filled 0/8 missing USD
#   [Domestic] Maize (white) | Bujumbura Rural, Burundi | 111 rows | filled 0/11 missing USD
#   [Domestic] Beans | Bujumbura Rural, Burundi | 136 rows | filled 0/10 missing USD
#   [Domestic] Vegetable oil | National Average, Burundi | 96 rows | filled 0/8 missing USD
#   [Domestic] Beans | National Average, Burundi | 135 rows | filled 0/9 missing USD
#   [Domestic] Cassava (flour) | Bujumbura Rural, Burundi | 136 rows | filled 0/11 missing USD
#   [Domestic] Maize (white) | Gitega, Burundi | 203 rows | filled 0/48 missing USD
#   [Domestic] Rice (low quality) | National Average, Burundi | 132 rows | filled 0/10 missing USD
#   [Domestic] Rice (low quality) | Bujumbura Mairie, Burundi | 132 rows | filled 0/12 missing USD
#   [Domestic] Cassava (flour) | Gitega, Burundi | 203 rows | filled 0/48 missing USD
#   [Domestic] Vegetable oil | Bujumbura Rural, Burundi | 95 rows | filled 0/8 missing USD
#   [Domestic] Rice (low quality) | Kirundo, Burundi | 132 rows | filled 0/11 missing USD
#   [Domestic] Maize (white) | Bujumbura Mairie, Burundi | 180 rows | filled 0/20 missing USD
#   [Domestic] Beans | Gitega, Burundi | 204 rows | filled 0/43 missing USD
#   [Domestic] Potatoes (sweet) | Gitega, Burundi | 203 rows | filled 0/47 missing USD
#   [Domestic] Beans | Bujumbura Mairie, Burundi | 180 rows | filled 0/18 missing USD
#   [Domestic] Maize (white) | Kirundo, Burundi | 203 rows | filled 0/58 missing USD
#   [Domestic] Beans | Kirundo, Burundi | 203 rows | filled 0/54 missing USD
#   [Domestic] Potatoes (sweet) | National Average, Burundi | 135 rows | filled 0/9 missing USD
#   [Domestic] Chicken (whole) | National Average, Belgium | 421 rows | filled 108/108 missing USD
#   [Domestic] Milk (raw) | National Average, Belgium | 253 rows | filled 0/0 missing USD
#   [Domestic] Eggs | National Average, Belgium | 349 rows | filled 36/36 missing USD
#   [Domestic] Sorghum | Cotonou, Benin | 156 rows | filled 0/37 missing USD
#   [Domestic] Rice | Natitingou, Benin | 138 rows | filled 0/34 missing USD
#   [Domestic] Cassava (gari) | Natitingou, Benin | 138 rows | filled 0/33 missing USD
#   [Domestic] Maize | Parakou, Benin | 156 rows | filled 0/48 missing USD
#   [Domestic] Sorghum | Parakou, Benin | 156 rows | filled 0/48 missing USD
#   [Domestic] Cassava (gari) | Parakou, Benin | 156 rows | filled 0/51 missing USD
#   [Domestic] Yam | Natitingou, Benin | 138 rows | filled 0/34 missing USD
#   [Domestic] Maize | Natitingou, Benin | 138 rows | filled 0/33 missing USD
#   [Domestic] Maize | Cotonou, Benin | 156 rows | filled 0/36 missing USD
#   [Domestic] Sorghum | Natitingou, Benin | 138 rows | filled 0/33 missing USD
#   [Domestic] Cassava (gari) | Cotonou, Benin | 156 rows | filled 0/36 missing USD
#   [Domestic] Rice | Cotonou, Benin | 156 rows | filled 0/36 missing USD
#   [Domestic] Rice | Parakou, Benin | 156 rows | filled 0/49 missing USD
#   [Domestic] Yam | Parakou, Benin | 156 rows | filled 0/52 missing USD
#   [Domestic] Yam | Cotonou, Benin | 156 rows | filled 0/36 missing USD
#   [Domestic] Rice (imported) | Hauts-Bassins Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Rice (imported) | Kongoussi, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Tenkodogo, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Est Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Bobo Dioulasso, Burkina Faso | 195 rows | filled 1/1 missing USD
#   [Domestic] Millet | Est Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Dédougou, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum (white) | Nord Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Centre Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Rice (imported) | Centre Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Sorghum (white) | Sahel Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Nouna, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Fada N'gourma, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Millet | Sahel Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Sorghum | Kongoussi, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum (white) | Hauts-Bassins Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Sorghum | Ouagadougou, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Ouagadougou, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Millet | Tenkodogo, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Fada N'gourma, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Nouna, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Millet | Dori, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Dédougou, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Bobo Dioulasso, Burkina Faso | 195 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Bobo Dioulasso, Burkina Faso | 195 rows | filled 1/2 missing USD
#   [Domestic] Rice (imported) | Dori, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Millet | Ouagadougou, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Dori, Burkina Faso | 242 rows | filled 1/1 missing USD
#   [Domestic] Sorghum (white) | Est Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Rice (imported) | Tenkodogo, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Sorghum | Dédougou, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Millet | Kongoussi, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Millet | Hauts-Bassins Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Fada N'gourma, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Rice (imported) | Sahel Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Millet | Nord Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Sorghum (white) | Centre Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Rice (imported) | Nord Region, Burkina Faso | 19 rows | filled 0/1 missing USD
#   [Domestic] Rice (imported) | Nouna, Burkina Faso | 218 rows | filled 1/1 missing USD
#   [Domestic] Soybean oil | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour, loose) | National Average, Bangladesh | 50 rows | filled 1/11 missing USD
#   [Domestic] Rice (coarse- BR-8/ 11/ Guti/ Sharna) | Dhaka, Bangladesh | 326 rows | filled 18/23 missing USD
#   [Domestic] Rice (Boro, hybrid, medium) | National Average, Bangladesh | 50 rows | filled 1/4 missing USD
#   [Domestic] Rice (Boro, hybrid, medium) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Rice (Boro, hybrid, coarse) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Rice (Aman, coarse) | National Average, Bangladesh | 50 rows | filled 1/10 missing USD
#   [Domestic] Rice (Aman, medium) | National Average, Bangladesh | 50 rows | filled 1/9 missing USD
#   [Domestic] Wheat (flour) | Dhaka, Bangladesh | 212 rows | filled 0/3 missing USD
#   [Domestic] Rice (Medium) | Dhaka, Bangladesh | 212 rows | filled 0/7 missing USD
#   [Domestic] Rice (coarse- BR-8/ 11/ Guti/ Sharna) | Dhaka, Bangladesh | 212 rows | filled 0/10 missing USD
#   [Domestic] Rice (Aman, medium) | National Average, Bangladesh | 50 rows | filled 1/3 missing USD
#   [Domestic] Palm oil | Tangail sadar, Bangladesh | 62 rows | filled 0/0 missing USD
#   [Domestic] Rice (Medium) | Dhaka, Bangladesh | 212 rows | filled 0/6 missing USD
#   [Domestic] Rice (Boro, hybrid, coarse) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Wheat grain (imported) | National Average, Bangladesh | 50 rows | filled 1/3 missing USD
#   [Domestic] Wheat (flour) | Dhaka, Bangladesh | 206 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, white, loose) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour, loose) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Wheat grain (imported) | National Average, Bangladesh | 50 rows | filled 1/11 missing USD
#   [Domestic] Rice (Aman, coarse) | National Average, Bangladesh | 50 rows | filled 1/10 missing USD
#   [Domestic] Wheat (flour, white, loose) | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Palm oil | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Soybean oil | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Palm oil | National Average, Bangladesh | 50 rows | filled 1/1 missing USD
#   [Domestic] Chicken (whole) | National Average, Bulgaria | 229 rows | filled 0/0 missing USD
#   [Domestic] Eggs | National Average, Bulgaria | 229 rows | filled 0/0 missing USD
#   [Domestic] Wheat (bread making quality) | National Average, Bulgaria | 229 rows | filled 0/0 missing USD
#   [Domestic] Milk (raw) | National Average, Bulgaria | 229 rows | filled 0/3 missing USD
#   [Domestic] Wheat (flour) | Minsk, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Bread (high grade flour) | National Average, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Bread (high grade flour) | Minsk, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Potatoes | Minsk, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Potatoes | National Average, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Wheat (flour) | National Average, Belarus | 205 rows | filled 205/205 missing USD
#   [Domestic] Onions (yellow) | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Beans (red, kidney) | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Maize (white) | Orange Walk, Belize | 83 rows | filled 0/3 missing USD
#   [Domestic] Chicken (whole) | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Beef meat | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Bananas | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Beans (black) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Bananas | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Rice | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Maize (yellow) | Orange Walk, Belize | 83 rows | filled 0/2 missing USD
#   [Domestic] Maize (yellow) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Cabbage | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Maize (white) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Beef meat | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Potatoes (Imported) | Punta Gorda, Belize | 68 rows | filled 0/18 missing USD
#   [Domestic] Beans (red, kidney) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Chicken (whole) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Beans (black) | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Chicken (whole) | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Beans (red, kidney) | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Oranges | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Beans (black) | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Oranges | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Rice | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Onions (yellow) | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Eggs | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Potatoes | Belize City, Belize | 68 rows | filled 0/33 missing USD
#   [Domestic] Cabbage | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Beef meat | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Potatoes (Imported) | Belize City, Belize | 68 rows | filled 0/15 missing USD
#   [Domestic] Potatoes (Imported) | Orange Walk, Belize | 67 rows | filled 0/10 missing USD
#   [Domestic] Bananas | Orange Walk, Belize | 83 rows | filled 0/1 missing USD
#   [Domestic] Eggs | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Potatoes | Punta Gorda, Belize | 68 rows | filled 0/34 missing USD
#   [Domestic] Oranges | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Cabbage | Belize City, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Onions (yellow) | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Eggs | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Potatoes | Orange Walk, Belize | 71 rows | filled 0/41 missing USD
#   [Domestic] Rice | Punta Gorda, Belize | 84 rows | filled 0/1 missing USD
#   [Domestic] Bread | La Paz, Bolivia (Plurinational State of) | 204 rows | filled 0/0 missing USD
#   [Domestic] Chicken (whole, without offals) | Santa Cruz, Bolivia (Plurinational State of) | 211 rows | filled 0/6 missing USD
#   [Domestic] Maize (yellow) | Cochabamba, Bolivia (Plurinational State of) | 216 rows | filled 0/7 missing USD
#   [Domestic] Quinoa | Chuquisaca, Bolivia (Plurinational State of) | 179 rows | filled 0/123 missing USD
#   [Domestic] Milk (raw) | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Chicken (whole, without offals) | Cochabamba, Bolivia (Plurinational State of) | 215 rows | filled 0/5 missing USD
#   [Domestic] Quinoa | Santa Cruz, Bolivia (Plurinational State of) | 185 rows | filled 0/108 missing USD
#   [Domestic] Bananas | Trinidad, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Quinoa | La Paz, Bolivia (Plurinational State of) | 179 rows | filled 0/33 missing USD
#   [Domestic] Chicken meat | Trinidad, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Sugar | Potosi, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | Potosi, Bolivia (Plurinational State of) | 180 rows | filled 0/6 missing USD
#   [Domestic] Quinoa | El Alto, Bolivia (Plurinational State of) | 112 rows | filled 0/5 missing USD
#   [Domestic] Bread | Tarija, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (first quality) | El Alto, Bolivia (Plurinational State of) | 112 rows | filled 0/4 missing USD
#   [Domestic] Bread | Trinidad, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Maize (yellow) | Santa Cruz, Bolivia (Plurinational State of) | 216 rows | filled 0/9 missing USD
#   [Domestic] Rice (first quality) | Tarija, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | Cochabamba, Bolivia (Plurinational State of) | 171 rows | filled 0/17 missing USD
#   [Domestic] Bread | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Chicken meat | La Paz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | La Paz, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Rice (first quality) | Trinidad, Bolivia (Plurinational State of) | 97 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | El Alto, Bolivia (Plurinational State of) | 113 rows | filled 0/4 missing USD
#   [Domestic] Rice (second quality) | Chuquisaca, Bolivia (Plurinational State of) | 179 rows | filled 0/23 missing USD
#   [Domestic] Potatoes (Desirée) | National Average, Bolivia (Plurinational State of) | 187 rows | filled 0/4 missing USD
#   [Domestic] Wheat (flour) | Oruro, Bolivia (Plurinational State of) | 180 rows | filled 0/127 missing USD
#   [Domestic] Sugar | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Bananas | Sucre, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Chicken (whole, without offals) | La Paz, Bolivia (Plurinational State of) | 215 rows | filled 0/4 missing USD
#   [Domestic] Maize (yellow) | Oruro, Bolivia (Plurinational State of) | 179 rows | filled 0/11 missing USD
#   [Domestic] Chicken (whole, without offals) | El Alto, Bolivia (Plurinational State of) | 112 rows | filled 0/4 missing USD
#   [Domestic] Maize (yellow) | Potosi, Bolivia (Plurinational State of) | 178 rows | filled 0/21 missing USD
#   [Domestic] Rice (first quality) | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | Oruro, Bolivia (Plurinational State of) | 180 rows | filled 0/26 missing USD
#   [Domestic] Wheat (flour, imported) | National Average, Bolivia (Plurinational State of) | 180 rows | filled 0/4 missing USD
#   [Domestic] Potatoes | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Eggs | La Paz, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Milk (raw) | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Potosi, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Sugar | Trinidad, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Bread | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Sugar | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Milk (raw) | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Eggs | Tarija, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, imported) | El Alto, Bolivia (Plurinational State of) | 113 rows | filled 0/4 missing USD
#   [Domestic] Sunflower oil | Trinidad, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | National Average, Bolivia (Plurinational State of) | 216 rows | filled 0/4 missing USD
#   [Domestic] Rice (second quality) | Oruro, Bolivia (Plurinational State of) | 179 rows | filled 0/8 missing USD
#   [Domestic] Sugar | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | Tarija, Bolivia (Plurinational State of) | 180 rows | filled 0/8 missing USD
#   [Domestic] Potatoes | Tarija, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (second quality) | Potosi, Bolivia (Plurinational State of) | 178 rows | filled 0/8 missing USD
#   [Domestic] Wheat (flour) | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Quinoa | Cochabamba, Bolivia (Plurinational State of) | 185 rows | filled 0/8 missing USD
#   [Domestic] Bananas | La Paz, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Cochabamba, Bolivia (Plurinational State of) | 211 rows | filled 0/11 missing USD
#   [Domestic] Bananas | Oruro, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | El Alto, Bolivia (Plurinational State of) | 114 rows | filled 0/4 missing USD
#   [Domestic] Milk (raw) | Trinidad, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (first quality) | Santa Cruz, Bolivia (Plurinational State of) | 212 rows | filled 0/6 missing USD
#   [Domestic] Quinoa | National Average, Bolivia (Plurinational State of) | 185 rows | filled 0/4 missing USD
#   [Domestic] Maize (yellow) | Tarija, Bolivia (Plurinational State of) | 179 rows | filled 0/18 missing USD
#   [Domestic] Maize (yellow) | National Average, Bolivia (Plurinational State of) | 216 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Santa Cruz, Bolivia (Plurinational State of) | 213 rows | filled 0/7 missing USD
#   [Domestic] Bread | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Maize (yellow) | La Paz, Bolivia (Plurinational State of) | 216 rows | filled 0/5 missing USD
#   [Domestic] Rice (second quality) | Santa Cruz, Bolivia (Plurinational State of) | 179 rows | filled 0/6 missing USD
#   [Domestic] Oranges | Sucre, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Eggs | Potosi, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, imported) | La Paz, Bolivia (Plurinational State of) | 180 rows | filled 0/4 missing USD
#   [Domestic] Sugar | Tarija, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Bananas | Tarija, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Eggs | Sucre, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Potatoes (Desirée) | La Paz, Bolivia (Plurinational State of) | 179 rows | filled 0/40 missing USD
#   [Domestic] Chicken (whole, without offals) | Oruro, Bolivia (Plurinational State of) | 179 rows | filled 0/8 missing USD
#   [Domestic] Rice (second quality) | La Paz, Bolivia (Plurinational State of) | 179 rows | filled 0/4 missing USD
#   [Domestic] Potatoes (Desirée) | Chuquisaca, Bolivia (Plurinational State of) | 180 rows | filled 0/10 missing USD
#   [Domestic] Chicken meat | Sucre, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (first quality) | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | Trinidad, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Maize (yellow) | Chuquisaca, Bolivia (Plurinational State of) | 179 rows | filled 0/8 missing USD
#   [Domestic] Wheat (flour) | La Paz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (first quality) | Oruro, Bolivia (Plurinational State of) | 179 rows | filled 0/8 missing USD
#   [Domestic] Oranges | La Paz, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Rice (second quality) | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Rice (second quality) | Tarija, Bolivia (Plurinational State of) | 179 rows | filled 0/13 missing USD
#   [Domestic] Wheat (flour, imported) | Tarija, Bolivia (Plurinational State of) | 180 rows | filled 0/11 missing USD
#   [Domestic] Rice (first quality) | La Paz, Bolivia (Plurinational State of) | 215 rows | filled 0/4 missing USD
#   [Domestic] Sunflower oil | Oruro, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, imported) | Chuquisaca, Bolivia (Plurinational State of) | 180 rows | filled 0/7 missing USD
#   [Domestic] Oranges | Trinidad, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Chicken meat | Santa Cruz, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | Sucre, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Quinoa | Oruro, Bolivia (Plurinational State of) | 179 rows | filled 0/8 missing USD
#   [Domestic] Chicken meat | Tarija, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Bread | Potosi, Bolivia (Plurinational State of) | 204 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, imported) | Santa Cruz, Bolivia (Plurinational State of) | 180 rows | filled 0/6 missing USD
#   [Domestic] Oranges | Santa Cruz, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Quinoa | Potosi, Bolivia (Plurinational State of) | 163 rows | filled 0/37 missing USD
#   [Domestic] Chicken meat | Oruro, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
#   [Domestic] Oranges | Oruro, Bolivia (Plurinational State of) | 91 rows | filled 0/0 missing USD
#   [Domestic] Chicken meat | Potosi, Bolivia (Plurinational State of) | 205 rows | filled 0/0 missing USD
# ...
#   [Domestic] Tomatoes | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Bananas | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Rice | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Fish (fresh) | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Onions | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Eggplants | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Apples | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | National Average, Türkiye | 44 rows | filled 0/0 missing USD
#   [Domestic] Rice | National Average, United Republic of Tanzania | 239 rows | filled 0/4 missing USD
#   [Domestic] Sorghum | National Average, United Republic of Tanzania | 68 rows | filled 0/2 missing USD
#   [Domestic] Beans | National Average, United Republic of Tanzania | 239 rows | filled 0/20 missing USD
#   [Domestic] Potatoes | National Average, United Republic of Tanzania | 68 rows | filled 0/1 missing USD
#   [Domestic] Maize | National Average, United Republic of Tanzania | 239 rows | filled 0/3 missing USD
#   [Domestic] Wheat | National Average, United Republic of Tanzania | 68 rows | filled 0/1 missing USD
#   [Domestic] Millet (bulrush) | National Average, United Republic of Tanzania | 68 rows | filled 0/1 missing USD
#   [Domestic] Millet (finger) | National Average, United Republic of Tanzania | 68 rows | filled 0/1 missing USD
#   [Domestic] Beans | National Average, Uganda | 192 rows | filled 0/1 missing USD
#   [Domestic] Maize (white) | National Average, Uganda | 177 rows | filled 0/5 missing USD
#   [Domestic] Cassava (flour) | National Average, Uganda | 192 rows | filled 0/11 missing USD
#   [Domestic] Maize (flour) | National Average, Uganda | 192 rows | filled 0/5 missing USD
#   [Domestic] Sorghum | National Average, Uganda | 177 rows | filled 0/6 missing USD
#   [Domestic] Vegetable oil | National Average, Uganda | 132 rows | filled 0/5 missing USD
#   [Domestic] Millet | National Average, Uganda | 177 rows | filled 0/15 missing USD
#   [Domestic] Wheat (flour, first grade, offer, EXW) | National Average, Ukraine | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat (flour, highest grade, offer, EXW) | National Average, Ukraine | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat (3rd class, bid, EXW, processing) | National Average, Ukraine | 302 rows | filled 1/1 missing USD
#   [Domestic] Maize (bid, EXW, processing) | National Average, Ukraine | 314 rows | filled 1/1 missing USD
#   [Domestic] Wheat | National Average, Uruguay | 191 rows | filled 0/0 missing USD
#   [Domestic] Rice | National Average, Uruguay | 191 rows | filled 0/0 missing USD
#   [Domestic] Maize (yellow) | National Average, Uruguay | 191 rows | filled 0/0 missing USD
#   [Domestic] Bananas | New York, United States of America | 157 rows | filled 0/0 missing USD
#   [Domestic] Papayas | New York, United States of America | 157 rows | filled 0/5 missing USD
#   [Domestic] Pineapples | New York, United States of America | 157 rows | filled 0/5 missing USD
#   [Domestic] Avocados | New York, United States of America | 157 rows | filled 0/5 missing USD
#   [Domestic] Organic Bananas | New York, United States of America | 157 rows | filled 0/0 missing USD
#   [Domestic] Bananas | National Average, United States of America | 372 rows | filled 60/60 missing USD
#   [Domestic] Mangoes | New York, United States of America | 157 rows | filled 0/1 missing USD
#   [Domestic] Wheat | Surkhandarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Tashkent City, Uzbekistan | 84 rows | filled 0/5 missing USD
#   [Domestic] Rice | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Namangan Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Apples | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Tashkent Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | Tashkent Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, first grade) | National Average, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, high grade) | National Average, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Tomatoes | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Kashkadarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cabbage | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Tomatoes | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Bukhara Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Milk (fresh) | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Eggs | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Namangan Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cabbage | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Bukhara Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Beef meat | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, high grade) | Tashkent Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Beans (white) | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Bread (first grade flour) | Tashkent Region, Uzbekistan | 60 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Djizzak Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Milk (fresh) | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Syrdarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Andijan Region, Uzbekistan | 48 rows | filled 0/1 missing USD
#   [Domestic] Cottonseed oil | Tashkent City, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Syrdarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Fergana Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Navoi Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Navoi Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Kashkadarya Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Fergana Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Andijan Region, Uzbekistan | 84 rows | filled 0/1 missing USD
#   [Domestic] Cottonseed oil | National Average, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Carrot | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Namangan Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Khorezm Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Beef meat | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Eggs | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Khorezm Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Surkhandarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Khorezm Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Apples | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Republic of Karakalpakistan, Uzbekistan | 47 rows | filled 0/0 missing USD
#   [Domestic] Beans (white) | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Syrdarya Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Samarkand Region, Uzbekistan | 47 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Fergana Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Grape | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Navoi Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Kashkadarya Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Tashkent City, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Bukhara Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Andijan Region, Uzbekistan | 84 rows | filled 0/1 missing USD
#   [Domestic] Wheat | Republic of Karakalpakistan, Uzbekistan | 83 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Djizzak Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour, first grade) | Tashkent Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Bread (first grade flour) | National Average, Uzbekistan | 60 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Samarkand Region, Uzbekistan | 83 rows | filled 0/0 missing USD
#   [Domestic] Grape | Tashkent Region, Uzbekistan | 84 rows | filled 0/2 missing USD
#   [Domestic] Wheat | Samarkand Region, Uzbekistan | 83 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Djizzak Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Republic of Karakalpakistan, Uzbekistan | 83 rows | filled 0/0 missing USD
#   [Domestic] Wheat | National Average, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Cottonseed oil | Surkhandarya Region, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Carrot | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | National Average, Uzbekistan | 48 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Rice | Tashkent Region, Uzbekistan | 84 rows | filled 0/0 missing USD
#   [Domestic] Rice (5% broken) | An Giang, Viet Nam | 89 rows | filled 1/2 missing USD
#   [Domestic] Rice (25% broken) | Dong Thap, Viet Nam | 218 rows | filled 1/7 missing USD
#   [Domestic] Rice (25% broken) | An Giang, Viet Nam | 218 rows | filled 1/2 missing USD
#   [Domestic] Rice (5% broken) | Bac Lieu, Viet Nam | 89 rows | filled 1/1 missing USD
#   [Domestic] Rice (25% broken) | Bac Lieu, Viet Nam | 89 rows | filled 1/1 missing USD
#   [Domestic] Rice (5% broken) | Dong Thap, Viet Nam | 89 rows | filled 1/1 missing USD
#   [Domestic] Taro | National Average, Samoa | 243 rows | filled 0/7 missing USD
#   [Domestic] Chicken meat | National Average, Samoa | 243 rows | filled 0/8 missing USD
#   [Domestic] Sugar | National Average, Samoa | 243 rows | filled 0/9 missing USD
#   [Domestic] Rice | National Average, Samoa | 243 rows | filled 0/8 missing USD
#   [Domestic] Sorghum | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Wheat | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Sorghum | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Millet | Hadramout, Yemen | 131 rows | filled 25/27 missing USD
#   [Domestic] Mutton meat | Hajjah, Yemen | 123 rows | filled 22/24 missing USD
#   [Domestic] Wheat (flour) | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Mutton meat | Hadramout, Yemen | 126 rows | filled 25/28 missing USD
#   [Domestic] Potatoes | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Onions | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Millet | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Potatoes | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Wheat | Hodeidah, Yemen | 127 rows | filled 19/25 missing USD
#   [Domestic] Chicken meat | Hajjah, Yemen | 123 rows | filled 22/24 missing USD
#   [Domestic] Wheat | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Tomatoes | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Tomatoes | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Vegetable oil | Hajjah, Yemen | 128 rows | filled 22/22 missing USD
#   [Domestic] Wheat (flour) | Hodeidah, Yemen | 127 rows | filled 19/25 missing USD
#   [Domestic] Vegetable oil | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Wheat (flour) | Hadramout, Yemen | 131 rows | filled 25/25 missing USD
#   [Domestic] Onions | Hadramout, Yemen | 131 rows | filled 25/26 missing USD
#   [Domestic] Chicken meat | Hadramout, Yemen | 126 rows | filled 25/28 missing USD
#   [Domestic] Milk (Full cream, Long life) | National Average, South Africa | 217 rows | filled 0/0 missing USD
#   [Domestic] Rice | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Wheat | Randfontein, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Maize (white) | Randfontein, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Potatoes | National Average, South Africa | 313 rows | filled 0/27 missing USD
#   [Domestic] Beef meat (Brisket, fresh) | National Average, South Africa | 217 rows | filled 0/2 missing USD
#   [Domestic] Bread (white) | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Maize (yellow) | Randfontein, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Bread (brown) | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Wheat (flour) | National Average, South Africa | 313 rows | filled 0/1 missing USD
#   [Domestic] Chicken meat (whole, fresh) | National Average, South Africa | 217 rows | filled 0/0 missing USD
#   [Domestic] Sunflower oil | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Fish (Hake, frozen) | National Average, South Africa | 217 rows | filled 0/0 missing USD
#   [Domestic] Sugar (white) | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Eggs | National Average, South Africa | 313 rows | filled 0/0 missing USD
#   [Domestic] Maize meal | National Average, South Africa | 49 rows | filled 0/0 missing USD
#   [Domestic] Meat (rump steak) | National Average, Zambia | 57 rows | filled 0/0 missing USD
#   [Domestic] Onions | National Average, Zambia | 87 rows | filled 0/17 missing USD
#   [Domestic] Eggs | National Average, Zambia | 86 rows | filled 0/0 missing USD
#   [Domestic] Breakfast maize meal | National Average, Zambia | 241 rows | filled 0/0 missing USD
#   [Domestic] Maize (white) | National Average, Zambia | 265 rows | filled 0/0 missing USD
#   [Domestic] White roller maize meal | National Average, Zambia | 241 rows | filled 0/0 missing USD
#   [Domestic] Maize meal | Epworth, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Beans | Epworth, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Maize meal | Gweru, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Vegetable oil | Epworth, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Maize meal | Mutare, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Maize meal | Masvingo, Zimbabwe | 21 rows | filled 0/0 missing USD
#   [Domestic] Rice | Epworth, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Maize meal | Bulawayo, Zimbabwe | 22 rows | filled 1/1 missing USD
#   [Domestic] Bread | Epworth, Zimbabwe | 22 rows | filled 1/1 missing USD
#
# ============================================================
# COMBINING AND SAVING
# ============================================================
#
# Total rows          : 493,714
# Missing price_usd   : 26,226
# Missing price_local : 26,226
#
# Fill method breakdown:
# fill_method
# original              482291
# implicit_rate           5706
# local_is_usd            3687
# hardcoded_rate_byr      1230
# hardcoded_rate_tmt       800
#
# Saved → all_commodity_prices.csv
